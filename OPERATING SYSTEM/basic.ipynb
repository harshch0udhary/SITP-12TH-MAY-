# %%
| Function           | Work                          | Example                       |
| ------------------ | ----------------------------- | ----------------------------- |
| `os.getcwd()`      | Get current working directory | `os.getcwd()`                 |
| `os.chdir(path)`   | Change current directory      | `os.chdir("D:/Python")`       |
| `os.listdir()`     | Show all files and folders    | `os.listdir()`                |
| `os.mkdir()`       | Create one folder             | `os.mkdir("Student")`         |
| `os.makedirs()`    | Create multiple folders       | `os.makedirs("Data/Student")` |
| `os.rmdir()`       | Delete empty folder           | `os.rmdir("Student")`         |
| `os.removedirs()`  | Delete nested empty folders   | `os.removedirs("A/B/C")`      |
| `os.remove()`      | Delete file                   | `os.remove("data.txt")`       |
| `os.rename()`      | Rename file/folder            | `os.rename("old","new")`      |
| `os.path.exists()` | Check file/folder exists      | `os.path.exists("Data")`      |
| `os.path.isfile()` | Check file exists             | `os.path.isfile("a.txt")`     |
| `os.path.isdir()`  | Check folder exists           | `os.path.isdir("Student")`    |
| `os.path.join()`   | Join file paths               | `os.path.join("A","B")`       |

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\SURFACE\\Desktop\\pyhton\\os'

# %%
path=r'c:\\Users\\SURFACE\\Desktop\\pyhton\\os'
os.listdir(path)
# Out:
# ['basic.ipynb', 'collage']

# %%
os.listdir(r'c:\\Users\\SURFACE\\Desktop\\pyhton\\os')
# Out:
# ['basic.ipynb', 'collage']

# %%
os.mkdir("hi")
# It is used for dicitonary create in any current file folder.

# %%
os.getcwd() # check the current dic.
# Out:
# 'c:\\Users\\SURFACE\\Desktop\\pyhton\\os'

# %%
os.listdir(r'c:\\Users\\SURFACE\\Desktop\\pyhton\\os')
# Out:
# ['basic.ipynb', 'collage', 'hi']

# %%
os.makedirs("hello\\data\\reports")

# %%
os.listdir(os.getcwd())
# Out:
# ['basic.ipynb', 'collage', 'hello', 'hi']

# %%
os.rmdir("hi")

# %%
os.rename("hello","collage")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 os.rename("hello","collage")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'hello' -> 'collage'

# %%
os.getcwd()
# Out:
# 'c:\\Users\\SURFACE\\Desktop\\pyhton\\AI'

# %%
os.listdir(os.getcwd())
# Out:
# ['collage']

# %%
os.chdir(r'c:\\Users\\SURFACE\\Desktop\\pyhton\AI')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\SURFACE\\Desktop\\pyhton\\AI'

# %%
path="c:\\Users\\SURFACE\\Desktop\\pyhton\\AI"

path1=r"c:\\Users\\SURFACE\\Desktop"
path2=r"pyhton\\AI"

complete_path=os.path.join(path1,path2)
print(complete_path)
print("final path:",os.listdir(complete_path))
# Out:
# c:\\Users\\SURFACE\\Desktop\pyhton\\AI
# final path: ['collage']

# %%
os.path.isfile(r"C:\Users\SURFACE\Desktop\pyhton\classes.ipynb")
# Out:
# True

# %%
os.path.isdir(r"c:\\Users\\SURFACE\\Desktop\pyhton")
# Out:
# True

# %%
os.path.exists(r"C:\Users\SURFACE\Desktop\pyhton\classes.ipynb")

#checking file will be exist or not.
# Out:
# True

# %%
os.get.size(r"C:\Users\SURFACE\Desktop\pyhton\classes.ipynb")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 os.get.size(r"C:\Users\SURFACE\Desktop\pyhton\classes.ipynb")
#
# NameError: name 'os' is not defined
