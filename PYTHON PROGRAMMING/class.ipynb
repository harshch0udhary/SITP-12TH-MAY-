# %%
classes in python<<<<<<<<<<<<<<

# %%
class Classname:
    pass

# %%
class Student:
    pass
#class keyword and student class.

# %%
class LastName:
    pass
# L and M are captial letter.
#from fastapi to import FASTAPI

# %%
class Student:
    name="HARSH"#class variable.
    pass

# %%
class Student:
    name="HARSH"
st=Student()### st is object and multiple objects can be created.
#Student>>>>>>Class
#st>>>>>Object
#name>>>>>Attribute(class variable)

# %%
class Student:
    name="Harsh"
    branch="CSE WITH AI"
    year="second year"
    roll_number="24EBKAI015"
    st=Student()

# %%
st.branch()

# %%
class Collage:
    Collage_name="BKBIET"
    Collage_address="pilani"
    Collage_sp=42
    riya=Collage()
    ritik=Collage()
    hemant=Collage()
    riya.Collage_name()

# %%
class Collage:
    College_name:"ARYA MAIN CAMPUS"
    def display(a):#arugement will be pass at (a,b,self, any values will be pass)
        pass

clg=Collage()
