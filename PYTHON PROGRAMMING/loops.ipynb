# %%
lst=[1,2,3,4]
for x in lst:
    if x==3:
        break # 
    print(x)
# Out:
# 1
# 2

# %%
lst=[1,2,3,4]
for x in lst:
    if x==3:
        continue
    print(x)
# Out:
# 1
# 2
# 4

# %%
lst=[1,2,3,4,5,65,["hello","hi","job"]]
print(lst[5][0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 lst=[1,2,3,4,5,65,["hello","hi","job"]]
# ----> 2 print(lst[5][0])
#
# TypeError: 'int' object is not subscriptable

# %%
#while condition:
   # block of code


x=1
while x<=5:
    print(x)
    x+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
x=10
while x>=3:
    print(x)
    x-=1
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
