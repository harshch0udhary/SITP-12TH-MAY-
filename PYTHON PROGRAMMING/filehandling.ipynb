# %% [markdown]
# | Mode   | Meaning                         |
# | ------ | ------------------------------- |
# | `"r"`  | Read file                       |
# | `"w"`  | Write file (overwrite old data) |
# | `"a"`  | Append data at end              |
# | `"x"`  | Create new file                 |

# %%
file =open("point.txt", 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 file =open("point.txt", 'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'point.txt'

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 file.read()
#
# NameError: name 'file' is not defined

# %%
# file.readline()
# file.readlines()
file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # file.readline()
#       2 # file.readlines()
# ----> 3 file.close()
#
# NameError: name 'file' is not defined

# %%
with open('poit.txt') as file:
    print(file.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 with open('poit.txt') as file:
#       2     print(file.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'poit.txt'

# %% [markdown]
# <!-- write mode  -->

# %%
file =open('poit.txt', 'w')
file.write("hiii how are you ? ")
file.close()
file =open('poit.txt', 'r')
file.read()
# Out:
# 'hiii how are you ? '

# %%
file =open('poit1.txt', 'w')
file.write("hiii how are you ? ")
file.close()
file =open('poit.txt', 'r')
file.read()
# Out:
# 'hiii how are you ? '

# %%
file =open('poit.txt', 'a')
file.write("File Handling in Python means working with files like creating, reading, writing, updating, and deleting files using Python code.")
file.close()

# %%
open('poit.txt', 'r').read()
# Out:
# 'hiii how are you ? File Handling in Python means working with files like creating, reading, writing, updating, and deleting files using Python code.'

# %%
file =open('filehandling.txt', 'a')
file.write("File Handling in Python means working with files like creating, reading, writing, updating, and deleting files using Python code.")
file.close()

# %%
# file.read()

# %%
file =open('filehandling2.txt', 'x')
file.write("File Handling in Python means working with files like creating, reading, writing, updating, and deleting files using Python code.")
file.close()
