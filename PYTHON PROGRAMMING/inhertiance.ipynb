# %%
* Inheritance is a feature of OOP (Object-Oriented Programming) where one class can use the properties and methods of another class.

* Parent Class / Base Class → The class whose properties are inherited.
* Child Class / Derived Class → The class that inherits properties.

        Inheritance helps in:

* Code reusability
* Reducing duplicate code
* Easy maintenance


Types of Inheritance in Python


| Type                     | Meaning                                    |
| ------------------------ | ------------------------------------------ |
| Single Inheritance       | One parent → One child                     |
| Multiple Inheritance     | Multiple parents → One child               |
| Multilevel Inheritance   | Grandparent → Parent → Child               |
| Hierarchical Inheritance | One parent → Multiple children             |
| Hybrid Inheritance       | Combination of different inheritance types |

# %%
 Single Inheritance       | One parent → One child 

class Collage:
    pass
class Student:
    pass

# %%
class Collage:
    Collage_name="BKBIET"
    Collage_address="jaipur"
    Collage_sp=42


    def show(a):
     print(a.Collage_name)
     print(a.Collage_address)
     print(a.Collage_sp)

class Student(Collage):
     collage_studentid="24ebkai015"
     collage_studentname="HARSH BALODA"
st=Student()
st.show()
print(st.collage_studentid)
print(st.Collage_address)
print(st.collage_studentname)
# Out:
# BKBIET
# jaipur
# 42
# 24ebkai015
# jaipur
# HARSH BALODA

# %%
| Multiple Inheritance     | Multiple parents → One child               

class A: #data will be inherited in class B
    pass
class B: # data will be Inherited in Class C
    pass
class C:
    pass

# %%
class Person:
    pass
class Teacher(Person):
    pass
class HOD(Teacher):
    pass

# %%
class Person:
    def Person_info(self):
        print("I AM A PERSON")
class Teacher(Person):
    def Teacher_info(self):
        print("I AM A TEACHER")
class HOD(Teacher):
    def HOD_info(self):
        print("I AM A HOD")
s1=HOD()
print(s1.HOD_info())
print(s1.Person_info())
print(s1.Teacher_info())
# Out:
# I AM A HOD
# None
# I AM A PERSON
# None
# I AM A TEACHER
# None

# %%
class Devloper:
    pass 
class Manager:
    pass 
class Team_leader(Devloper,Manager)
    pass

# %%
class Devloper:
    def codding(self):
        print("code likhna")
class Manager:
    def meeting(self):
        print("eska ek hi kaam hai")
class Team_leader(Devloper,Manager):
    def project(self):
        print("project ko handle karna")
team=Team_leader()

team.codding()

print(team.project())
print(team.meeting())
# Out:
# code likhna
# project ko handle karna
# None
# eska ek hi kaam hai
# None

# %%
class Company_01:
    def coding(self):
        print("code likhna")
class Company_02:
    def assigment(self):
        print("eska ek hi kaam hai assigment dena")
class Upflairs(Company_01,Company_02):
    def project(self):
        print("work done")
Coreteam=Upflairs()

Coreteam.coding()
Coreteam.project()
Coreteam.assigment()
print(Coreteam.coding())
print(Coreteam.project())
print(Coreteam.assigment())
# Out:
# code likhna
# work done
# eska ek hi kaam hai assigment dena
# code likhna
# None
# work done
# None
# eska ek hi kaam hai assigment dena
# None

# %%
| Multilevel Inheritance   | Grandparent → Parent → Child               |


class A: #GRANDPARENT CLASS
    pass
class B:#PARENT CLASS
    pass
class C:#CHILD CLASS
    pass

# %%
| Hierarchical Inheritance | One parent → Multiple children             |

class A:#only one parent class
    pass
class B:#child class 
    pass
class C:#child class 
    pass

# %%
class Devloper:
    def codding(self):
        print("code likhna")
class Manager(Devloper):
    def meeting(self):
        print("eska ek hi kaam hai")
class Team_leader(Devloper):
    def project(self):
        print("project ko handle karna")


team=Team_leader()

team.codding()

print(team.project())
# Out:
# code likhna
# project ko handle karna
# None

# %%
| Hybrid Inheritance       | Combination of different inheritance types |


class A:
    pass
class B:#properties excess foer class A
    pass
class c:#properties excess from class A
    pass
class D:#that can be defined for class B and C
    pass
# Out:
#   Cell In[10], line 1
#     | Hybrid Inheritance       | Combination of different inheritance types |
#     ^
# SyntaxError: invalid syntax

# %%
class A:
    def displayA(self):
        print("Class A")
class B(A):
    def displayB(self):
        print("Class B")
class C(A):
    def displayC(self):
        print("Class C")
class D(B, C):
    def displayD(self):
        print("Class D")


obj = D()

obj.displayA()
obj.displayB()
obj.displayC()
obj.displayD()
# Out:
# Class A
# Class B
# Class C
# Class D

# %%
print(obj.displayA())
obj.displayB()
obj.displayC()
obj.displayD()
# Out:
# Class A
# None
# Class B
# Class C
# Class D
