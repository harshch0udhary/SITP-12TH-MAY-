# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\SURFACE\Desktop\MY PROJECTS\DATA\Walmart_Sales.csv")
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df.head()   # it is used for first five rows can be output.
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df.head(10)#it is used 10 rows can be in print
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
# 5      1  12-03-2010    1439541.59             0        57.79       2.667
# 6      1  19-03-2010    1472515.79             0        54.58       2.720
# 7      1  26-03-2010    1404429.92             0        51.45       2.732
# 8      1  02-04-2010    1594968.28             0        62.27       2.719
# 9      1  09-04-2010    1545418.53             0        65.86       2.770
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# ...

# %%
df.tail()#it is used for last five output in rows can be print
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667

# %%
df.tail(17)#It is using for 17 tails value.
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6418     45  06-07-2012     843361.10             0        82.99       3.475
# 6419     45  13-07-2012     749817.08             0        79.97       3.523
# 6420     45  20-07-2012     737613.65             0        78.89       3.567
# 6421     45  27-07-2012     711671.58             0        77.20       3.647
# 6422     45  03-08-2012     725729.51             0        76.58       3.654
# 6423     45  10-08-2012     733037.32             0        78.65       3.722
# 6424     45  17-08-2012     722496.93             0        75.71       3.807
# 6425     45  24-08-2012     718232.26             0        72.62       3.834
# 6426     45  31-08-2012     734297.87             0        75.09       3.867
# 6427     45  07-09-2012     766512.66             1        75.70       3.911
# 6428     45  14-09-2012     702238.27             0        67.87       3.948
# ...

# %%
df.info()
# it is used for information of any table
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   str
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), str(1)
# memory usage: 402.3 KB

# %%
df.columns    
# It is used for what columns can be used in tables.
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='str')

# %%
df['Store'] #it used for access any columns.
df[['Store']] #it is used for acess any column in a tabular form
# Out:
#       Store
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 6430     45
# 6431     45
# 6432     45
# 6433     45
# 6434     45
#
# [6435 rows x 1 columns]

# %%
df['Date']
# Out:
# 0       05-02-2010
# 1       12-02-2010
# 2       19-02-2010
# 3       26-02-2010
# 4       05-03-2010
#            ...
# 6430    28-09-2012
# 6431    05-10-2012
# 6432    12-10-2012
# 6433    19-10-2012
# 6434    26-10-2012
# Name: Date, Length: 6435, dtype: str

# %%
df['Weekly_Sales']
# Out:
# 0       1643690.90
# 1       1641957.44
# 2       1611968.17
# 3       1409727.59
# 4       1554806.68
#            ...
# 6430     713173.95
# 6431     733455.07
# 6432     734464.36
# 6433     718125.53
# 6434     760281.43
# Name: Weekly_Sales, Length: 6435, dtype: float64

# %%
df['Holiday_Flag']
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 6430    0
# 6431    0
# 6432    0
# 6433    0
# 6434    0
# Name: Holiday_Flag, Length: 6435, dtype: int64

# %%
df['Temperature']
# Out:
# 0       42.31
# 1       38.51
# 2       39.93
# 3       46.63
# 4       46.50
#         ...
# 6430    64.88
# 6431    64.89
# 6432    54.47
# 6433    56.47
# 6434    58.85
# Name: Temperature, Length: 6435, dtype: float64

# %%
df['Fuel_Price']
# Out:
# 0       2.572
# 1       2.548
# 2       2.514
# 3       2.561
# 4       2.625
#         ...
# 6430    3.997
# 6431    3.985
# 6432    4.000
# 6433    3.969
# 6434    3.882
# Name: Fuel_Price, Length: 6435, dtype: float64

# %%
df['CPI']
# Out:
# 0       211.096358
# 1       211.242170
# 2       211.289143
# 3       211.319643
# 4       211.350143
#            ...
# 6430    192.013558
# 6431    192.170412
# 6432    192.327265
# 6433    192.330854
# 6434    192.308899
# Name: CPI, Length: 6435, dtype: float64

# %%
df['Unemployment']
# Out:
# 0       8.106
# 1       8.106
# 2       8.106
# 3       8.106
# 4       8.106
#         ...
# 6430    8.684
# 6431    8.667
# 6432    8.667
# 6433    8.667
# 6434    8.667
# Name: Unemployment, Length: 6435, dtype: float64

# %%
df[['Store', 'Date', 'Weekly_Sales']]
# Out:
#       Store        Date  Weekly_Sales
# 0         1  05-02-2010    1643690.90
# 1         1  12-02-2010    1641957.44
# 2         1  19-02-2010    1611968.17
# 3         1  26-02-2010    1409727.59
# 4         1  05-03-2010    1554806.68
# ...     ...         ...           ...
# 6430     45  28-09-2012     713173.95
# 6431     45  05-10-2012     733455.07
# 6432     45  12-10-2012     734464.36
# 6433     45  19-10-2012     718125.53
# 6434     45  26-10-2012     760281.43
#
# [6435 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='str')

# %%
df.shape
# Out:
# (6435, 8)

# %%
df.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='str')

# %%
df.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
df.drop('Date', axis=1)
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
plt.scatter(df["Holiday_Flag"],df["Weekly_Sales"])
plt.xlabel("Weekly_Sales")
plt.ylabel("Holiday_Flag")
plt.title("Weekly_SalesvsHoliday_Flag")
plt.show()

# %%
plt.scatter(df["Temperature"],df["Weekly_Sales"])
plt.xlabel("Temperature")
plt.ylabel("Weekly_Sales")
plt.title("TemperaturevsWeekly_Sales")
plt.show()

# %%
plt.scatter(df["Fuel_Price"],df["Weekly_Sales"])
plt.xlabel("Fuel_Price")
plt.ylabel("Weekly_Sales")
plt.title("Fuel_PricevsWeekly_Sales")
plt.show()

# %%
plt.scatter(df["CPI"],df["Weekly_Sales"])
plt.xlabel("CPI")
plt.ylabel("Holiday_Flag")
plt.title("CPIvsHoliday_Flag")
plt.show()

# %%
plt.scatter(df["Unemployment"],df["Weekly_Sales"])
plt.xlabel("Unemployment")
plt.ylabel("Holiday_Flag")
plt.title("UnemploymentvsHoliday_Flag")
plt.show()

# %%
#agr kisi me null value ho tb
#df.isnull().sum()
#df.["temperature"].isnull().sum()
#null values k us column ki average value use krni h 
#df["Temperature"].fillna(df["Temperature"].median)
#df=df["Temperature"].fillna(df["Temperature"].median)
#df.isnull().sum()
# to check if any value is missing
#df.isnull().sum()

# %%
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
plt.hist(
    df["Weekly_Sales"],
    bins=30
)
plt.show()

# %%
plt.hist(
    df["Temperature"],
    bins=30
)
plt.show()

# %%
plt.hist(
    df["CPI"],
    bins=30
)
plt.show()

# %%
plt.hist(
    df["Holiday_Flag"],
    bins=30
)
plt.show()

# %%
plt.hist(
    df["Fuel_Price"],
    bins=30
)
plt.show()

# %%
plt.hist(
    df["Unemployment"],
    bins=30
)
plt.show()

# %%
plt.hist(
    df["Store"],
    bins=30
)
plt.show()

# %%
df.dtypes
# Out:
# Store             int64
# Date                str
# Weekly_Sales    float64
# Holiday_Flag      int64
# Temperature     float64
# Fuel_Price      float64
# CPI             float64
# Unemployment    float64
# dtype: object

# %%
y=df["Weekly_Sales"]

# %%
x= df.drop("Weekly_Sales", axis=1)

# %%
print(x.head())
print(y.head())
# Out:
#    Store        Date  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0      1  05-02-2010             0        42.31       2.572  211.096358
# 1      1  12-02-2010             1        38.51       2.548  211.242170
# 2      1  19-02-2010             0        39.93       2.514  211.289143
# 3      1  26-02-2010             0        46.63       2.561  211.319643
# 4      1  05-03-2010             0        46.50       2.625  211.350143
#
#    Unemployment
# 0         8.106
# 1         8.106
# 2         8.106
# 3         8.106
# 4         8.106
# 0    1643690.90
# 1    1641957.44
# 2    1611968.17
# 3    1409727.59
# 4    1554806.68
# Name: Weekly_Sales, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train, y_test=train_test_split(
    x,
    y,
    test_size=0.20,
    random_state=42
)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (5148, 7)
# (1287, 7)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
X.dtypes
# Out:
# Store             int64
# Weekly_Sales    float64
# Holiday_Flag      int64
# Temperature     float64
# Fuel_Price      float64
# CPI             float64
# Unemployment    float64
# dtype: object

# %%
y_pred = model.predict(X_test)
print(y_pred[:10])
# Out:
# [1138800.32 1304850.67 1769296.25 1077640.13  428851.99 1004523.59
#  1523410.71 1014898.78 1955896.59  958667.23]

# %%
from sklearn.metrics import accuracy_score

# %%
""" for checking the accuracy of the model trained """
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print("R2 Score:", r2)
# Out:
# R2 Score: 1.0
