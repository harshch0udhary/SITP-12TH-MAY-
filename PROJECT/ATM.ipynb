# %%
#ATM MACHINE>>>>>>
print("<<<<<<<<<<<<<<<    WELCOME TO ATM MACHINE    >>>>>>>>>>>")

class ATM:
    def __init__(self, balance):
        self.balance = balance

    def check_balance(self):
        print("CURRENT BALANCE:", self.balance)

    def deposit(self, amount):
        self.balance += amount
        print("DEPOSITED AMOUNT:", amount)

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print("WITHDRAWN AMOUNT :", amount)
        else:
            print("Insufficient Balance")


Accountnumber=input("ENTER YOUR ACCOUNT NO.:")
pin=input("ENTER YOUR PIN:")

if  Accountnumber=='123456789' and pin=='001':
    print("YOUR ACCOUNT NO:",Accountnumber)  # print the account no.
    print("LOGIN SUCCESSFUL")
     # Create ATM object
    atm = ATM(500000)

    # Check initial balance
    atm.check_balance()

    # User enters deposit amount
    deposit_amount = float(input("ENTER THE DEPOSIT AMOUNT: "))
    atm.deposit(deposit_amount)

    # User enters withdrawal amount
    withdraw_amount = float(input("ENTER THE AMOUNT YOU WITHDRAW:"))
    atm.withdraw(withdraw_amount)

    # Check final balance
    atm.check_balance()
    
    print("<<<<<<<<<<<  THANK YOU FOR VISITING  >>>>>>>>>>")
else:
    print("INVALID ACCOUNT NUMBER OR PIN")
    print("PLEASE CHECK YOUR ACCOUNT NO. OR PIN")
# Out:
# <<<<<<<<<<<<<<<    WELCOME TO ATM MACHINE    >>>>>>>>>>>
# INVALID ACCOUNT NUMBER OR PIN
# PLEASE CHECK YOUR ACCOUNT NO. OR PIN
